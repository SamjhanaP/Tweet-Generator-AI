# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /private/var/folders/zw/pbfcsf_s1yd6979g_17tgpzm0000gn/T/pip-req-build-qzi17p0_
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev120+g660b8c7-py3-none-any.whl size=50982 sha256=b22548206561776392d0931f4e2e653819c47ae6b7600d77624c75b6619c6842
#   Stored in directory: /private/var/folders/zw/pbfcsf_s1yd6979g_17tgpzm0000gn/T/pip-ephem-wheel-cache-is5yer4e/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# define download tweets function with username parameter,

import snscrape.modules.twitter as sntwitter
import pandas as pd

def download_tweets(username, tweets_count = 100):
    print(f"Downloading for {username}")
    
    tweets = []

    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'from:{username}').get_items()):
        if i >= tweets_count:
            break
        tweets.append([tweet.date, tweet.id, tweet.content, username])

    # Creating a dataframe from the tweets list above 
    tweets_df = pd.DataFrame(tweets, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
    tweets_df.to_csv(f"data/tweets-raw-{username}.csv", index=False)
    print(f"Downloaded for {username}")
    print("-----------------------------------")

# %%
from get_usernames import get_usernames
usernames = get_usernames()

for username in usernames:
    download_tweets(username, tweets_count=1000)

print("------------Downloaded----------------")
# Out:
# ...
# Downloaded for BarackObama
# -----------------------------------
# ...
# Downloaded for katyperry
# -----------------------------------
# ...
# Downloaded for kanyewest
# -----------------------------------
# ...
# Downloaded for rihanna
# -----------------------------------
# ...
# Downloaded for arianagrande
# -----------------------------------
# ...
# Downloaded for jtimberlake
# -----------------------------------
# ...
# Downloaded for justinbieber
# -----------------------------------
# ...
# Downloaded for billgates
# -----------------------------------
# ...
# Downloaded for elonmusk
# -----------------------------------
# ...
# Downloaded for shakira
# -----------------------------------
# ...
# Downloaded for brunomars
# -----------------------------------
# ...
# Downloaded for wizkhalifa
# -----------------------------------
# ...
# Downloaded for harry_styles
# -----------------------------------
# ...
# Downloaded for Cristiano
# -----------------------------------
# ...
# Downloaded for neymarjr
# -----------------------------------
# ...

# %% [markdown]
# ### About snscrape
# #### Attributes of API response of package {snscrape}
# ![image.png](attachment:3114b4b6-5ab2-48e3-9fad-f74d12177bd0.png)
#
# #### https://betterprogramming.pub/how-to-scrape-tweets-with-snscrape-90124ed006af
